# %% [markdown]
# ### Answer 1

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('Image 1.png')
brainpic.show()

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('Image 2.png')
brainpic.show()

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#the simplest way to open and display an image uses the novice module from skimage
brainpic = novice.open('Image 3.png')
brainpic.show()

# %% [markdown]
# ### Answer 2

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

#it is possible that in some installations pyDICOM won't be available in which case you will have to install it through pip

# Get file
RefDs = dicom.read_file('IM_0270.dcm')
# Let's print all the Metadata here
print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
# (0008, 0012) Instance Creation Date              DA: '20171115'
# (0008, 0013) Instance Creation Time              TM: '111956'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.34055.5
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.34055.5.0.4164.2017111511040850278
# (0008, 0020) Study Date                          DA: '20171115'
# (0008, 0021) Series Date                         DA: '20171115'
# (0008, 0022) Acquisition Date                    DA: '20171115'
# (0008, 0023) Content Date                        DA: '20171115'
# (0008, 0030) Study Time                          TM: '102824'
# (0008, 0031) Series Time                         TM: '110230.23000'
# ...

# %% [markdown]
# As per the metadata it is observed that the scanning sequence or the MR sequence is "Spinning Echo". The twomain parameters for these are :-
# 1.TE or Echo time - When the intensity of the pulse reaches from minimum to maximum the time take for that is know as Echo time.
# 2.TR or Relaxation time - The tme between the two sucessive excitation pulses.
#
# In regular SE sequences, TR is about 100 to 3000 msTR is the time allowed for longitudinal magnetization torecover (T1 relaxation)The longer the TR is, the more complete thelongitudinal magnetization recovery will beIf the TR is short, not all tissues will have undergonecomplete T1 relaxation and image contrast willbecome more dependent on the T1 relaxation processWith a regular SE sequence, only one line is filledduring a repetition (which lasts for time TR). The timeof acquisition (TA) of the full k-space is therefore proportional to the TR (TA = TR * number of lines).
#
# The echo concerns transverse magnetization and isthe result of spin re-phasing due to the 180°RF pulseapplied at time TE/2The 180°RF pulse is responsible for a cancelation ofspin de-phasing caused by static fieldinhomogeneities: transverse magnetization decay istherefore T2-dependent instead of T2*-dependentSE sequences serve as reference for tissue contrast

# %% [markdown]
# ### Answer 3

# %% [markdown]
# The acquisition matrix found is [0, 400, 319, 0], since the pixel information is Rows : 512 and Columns : 512 as they are different from the metadata we can conclude that as per the defination of acquisition matrix it states that the number of non dependent bit values in every direction can have muktile values in any direction. Pixel information does not change while reconstructing the image while the acquistion image may change.

# %% [markdown]
# ### Answer 4

# %% [markdown]
# The frequency which is provided in metadata refers to the imaging frequency , The value of the frequency may change with the different scanners as the frequencies have been set by default via manufacturers . The reason for the change in frequency is due to the different parameters taken by manufatcurer to analyse the data.

# %% [markdown]
# ### Answer 5

# %% [markdown]
# While the laborartory we saw different coils for the MRI of different on=bjects with different sizes, there were sevral coils and with sizes accoring to the shape of the body or pateint . The observations which we observed are :-
#
# -> The size of the coil mmatters as per the shape of the object of study , if the coil doesnt fit the shape of the object the observation may differ.
#
# -> The diameter of the coil is a important factor for the measurement as the object should not be greater then the size of the coil's diameter or else it will show the result of the area which is only covered under the coil.
